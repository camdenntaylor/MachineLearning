# %%
import pandas as pd

# Business case: ML pipelone: predict charges for FUTURE customers
df_ins = pd.read_csv(r'C:\Users\camde\OneDrive - Brigham Young University\IS JUNIOR CORE-Camdens-Laptop\IS 455\univariate_automation\insurance.csv')
display(df_ins.head())

# Business case: Data analytics, build report presentation for key indicator analysis
df_nba = pd.read_csv(r'C:\Users\camde\OneDrive - Brigham Young University\IS JUNIOR CORE-Camdens-Laptop\IS 455\nbastats\nba_salaries.csv')
display(df_nba.head())

# Business case: predict salary for EXISTING players
df_air = pd.read_csv(r'C:\Users\camde\OneDrive - Brigham Young University\IS JUNIOR CORE-Camdens-Laptop\IS 455\univariate_automation\airline_satisfaction.csv')
df_air.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#    Unnamed: 0        Player Name    Salary Position  Age     Team  GP  GS  \
# 0           0      Stephen Curry  48070014       PG   34      GSW  56  56
# 1           1          John Wall  47345760       PG   32      LAC  34   3
# 2           2  Russell Westbrook  47080179       PG   34  LAL/LAC  73  24
# 3           3       LeBron James  44474988       PF   38      LAL  55  54
# 4           4       Kevin Durant  44119845       PF   34  BRK/PHO  47  47
#
#      MP    FG  ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  \
# 0  34.7  10.0  ...  0.7  5.4  6.1  6.3  0.9  0.4  3.2  2.1  29.4
# ...

# %% [markdown]
# ###CREATING UNIVARIATE_STATS FUNCTION###

# %%
def univariate_stats(df, roundto = 4):
    import pandas as pd

    df_results = pd.DataFrame(columns=['dtype', 'count', 'missing', 'unique', 'mode', 
                                       'min', 'q1', 'median', 'q3', 'max', 
                                       'mean', 'std', 'skew', 'kurt'])
    
    for col in df:
        print(col)
        dtype = df[col].dtype
        count = df[col].count()
        missing = df[col].isna().sum()
        unique = df[col].nunique()
        mode = df[col].mode()[0]
        
        if pd.api.types.is_numeric_dtype(df[col]):
            min = df[col].min()
            q1 = df[col].quantile(0.25)
            median = df[col].median()
            q3 = df[col].quantile(0.75)
            max = df[col].max()
            mean = df[col].mean()
            std = df[col].std()
            skew = df[col].skew()
            kurt = df[col].kurt()

            df_results.loc[col] = [dtype, count, missing, unique, mode, 
                                   round(min, roundto), round(q1, roundto), round(median, roundto),
                                    round(q3, roundto), round(max, roundto), round(mean, roundto), 
                                    round(std, roundto), round(skew, roundto), round(kurt, roundto)]
        
        else:
            df_results.loc[col] = [dtype, count, missing, unique, mode, "", "", "", "", "", "", "", "", ""]


    return df_results

# %%
# importing newly written function from external file
import sys
sys.path.append(r'C:\Users\camde\OneDrive - Brigham Young University\IS JUNIOR CORE-Camdens-Laptop\IS 455\myfunctions')
import myfunctions as my

my.univariate_stats(df_ins, 2)
# Out:
#             dtype  count  missing  unique       mode      min       q1  \
# age         int64   1338        0      47         18       18     27.0
# sex        object   1338        0       2       male
# bmi       float64   1338        0     548       32.3    15.96     26.3
# children    int64   1338        0       6          0        0      0.0
# smoker     object   1338        0       2         no
# region     object   1338        0       4  southeast
# charges   float64   1338        0    1337  1639.5631  1121.87  4740.29
#
#            median        q3       max      mean       std  skew  kurt
# age          39.0      51.0        64     39.21     14.05  0.06 -1.25
# sex
# bmi          30.4     34.69     53.13     30.66       6.1  0.28 -0.05
# children      1.0       2.0         5      1.09      1.21  0.94   0.2
# smoker
# region
# charges   9382.03  16639.91  63770.43  13270.42  12110.01  1.52  1.61

# %% [markdown]
# ###data cleaning notes###
# - correct skewness on charges and bmi
# - make a second version of children that is an object
# - object features appear to be fine, but need to confirm with count plots

# %%
my.univariate_stats(df_nba, 2)
# Out:
#                      dtype  count  missing  unique        mode   min  \
# Unnamed: 0           int64    467        0     467           0     0
# Player Name         object    467        0     467  AJ Griffin
# Salary               int64    467        0     354      508891  5849
# Position            object    467        0       9          SG
# Age                  int64    467        0      22          23    19
# Team                object    467        0      75         SAC
# GP                   int64    467        0      80          67     1
# GS                   int64    467        0      79           0     0
# MP                 float64    467        0     255         5.6   1.8
# FG                 float64    467        0      96         2.1   0.0
# FGA                float64    467        0     157         1.0   0.0
# FG%                float64    466        1     227         0.5   0.0
# 3P                 float64    467        0      39         0.0   0.0
# ...
